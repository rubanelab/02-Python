# %% [markdown]
# ### **Extra Assignment: Level-1**

# %%
# print Statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input
institute_name = input("Enter your institute name? :")
# Out:
# Enter your institute name? :HOPE AI

# %%
# Buy inputs
name = input("Enter your name: ")
age = input("Enter your age: ")
school = input("Enter your school name: ")
degree = input("Enter your drgree: ")
# Out:
# Enter your name: Varatharuban B
# Enter your age: 42
# Enter your school name: University of Colombo
# Enter your drgree: BSc Computer Science

# %%
# Addition
a = 43
b = 34
add = a + b

print("a =", a)
print("b =", b)
print("add =", add)
# Out:
# a = 43
# b = 34
# add = 77

# %%
# Subtraction
a = 43
b = 34
sub = a - b

print("a =", a)
print("b =", b)
print("Sub =", sub)
# Out:
# a = 43
# b = 34
# Sub = 9

# %%
# Multiplication
a = 63
b = 97
mul = a * b

print("a =", a)
print("b =", b)
print("Mul =", mul)
# Out:
# a = 63
# b = 97
# Mul = 6111

# %%
# Division
a = 76
b = 31
division_float = a / b

print("a =", a)
print("b =", b)
print("Float Div =", division_float)
# Out:
# a = 76
# b = 31
# Float Div = 2.4516129032258065

# %%
# Floor division
a = 76
b = 31
division_floor = a // b

print("a =", a)
print("b =", b)
print("Floor Div =", division_floor)
# Out:
# a = 76
# b = 31
# Floor Div = 2

# %%
# Modulo
a = 76
b = 31
modulo = a % b

print("a =", a)
print("b =", b)
print("Modulo =", modulo)
# Out:
# a = 76
# b = 31
# Modulo = 14

# %%
# Power
a = 4
b = 4
power = a ** b

print("a =", a)
print("b =", b)
print("Power =", power)
# Out:
# a = 4
# b = 4
# Power = 256
